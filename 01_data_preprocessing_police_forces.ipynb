# %% [markdown]
# Loading and Exploring Data

# %%
import os 
import pandas as pd
base_path = r"C:/Police forces"
print("Base path:", base_path)
# Out:
# Base path: C:/Police forces

# %%
#verify the folder exists and list contents
print("Exists?", os.path.exists(base_path))
print("Contents:", os.listdir(base_path))
# Out:
# Exists? True
# Contents: ['Dyfed-Powys Police', 'Gwent Police', 'North Wales Police', 'South Wales Police']

# %% [markdown]
# Load all CSVs

# %%
#load all CSVs under C:\Police forces\{force}\*.csv
all_data = []

for force_folder in os.listdir(base_path):
    force_path = os.path.join(base_path, force_folder)
    
    # Skip if not a directory
    if not os.path.isdir(force_path):
        continue
    
    # Walk through all subfolders
    for root, dirs, files in os.walk(force_path):
        for file in files:
            if file.endswith(".csv"):
                file_path = os.path.join(root, file)
                print(f"Loading: {file_path}")
                
                try:
                    df_temp = pd.read_csv(file_path)
                    df_temp["PoliceForce"] = force_folder   # Label each row
                    all_data.append(df_temp)
                except Exception as e:
                    print("Error reading file:", file_path, e)

# Combine all CSVs into one DataFrame
if all_data:
    df = pd.concat(all_data, ignore_index=True)
    print("✅ Data loaded successfully!")
    print("Rows:", len(df))
    print("Columns:", len(df.columns))
else:
    print("❌ No CSV files found — check folder structure.")
# Out:
# Loading: C:/Police forces\Dyfed-Powys Police\2023-08\2023-08-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2023-09\2023-09-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2023-10\2023-10-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2023-11\2023-11-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2023-12\2023-12-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-01\2024-01-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-02\2024-02-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-03\2024-03-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-04\2024-04-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-05\2024-05-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-06\2024-06-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-07\2024-07-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-08\2024-08-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-09\2024-09-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-10\2024-10-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-11\2024-11-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2024-12\2024-12-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-01\2025-01-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-02\2025-02-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-03\2025-03-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-04\2025-04-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-05\2025-05-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-06\2025-06-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-07\2025-07-dyfed-powys-street.csv
# Loading: C:/Police forces\Dyfed-Powys Police\2025-08\2025-08-dyfed-powys-street.csv
# Loading: C:/Police forces\Gwent Police\2023-08\2023-08-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2023-09\2023-09-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2023-10\2023-10-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2023-11\2023-11-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2023-12\2023-12-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-01\2024-01-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-02\2024-02-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-03\2024-03-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-04\2024-04-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-05\2024-05-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-06\2024-06-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-07\2024-07-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-08\2024-08-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-09\2024-09-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-10\2024-10-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-11\2024-11-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2024-12\2024-12-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-01\2025-01-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-02\2025-02-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-03\2025-03-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-04\2025-04-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-05\2025-05-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-06\2025-06-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-07\2025-07-gwent-street.csv
# Loading: C:/Police forces\Gwent Police\2025-08\2025-08-gwent-street.csv
# Loading: C:/Police forces\North Wales Police\2023-08\2023-08-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2023-09\2023-09-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2023-10\2023-10-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2023-11\2023-11-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2023-12\2023-12-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-01\2024-01-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-02\2024-02-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-03\2024-03-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-04\2024-04-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-05\2024-05-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-06\2024-06-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-07\2024-07-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-08\2024-08-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-09\2024-09-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-10\2024-10-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-11\2024-11-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2024-12\2024-12-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-01\2025-01-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-02\2025-02-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-03\2025-03-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-04\2025-04-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-05\2025-05-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-06\2025-06-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-07\2025-07-north-wales-street.csv
# Loading: C:/Police forces\North Wales Police\2025-08\2025-08-north-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2023-08\2023-08-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2023-09\2023-09-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2023-10\2023-10-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2023-11\2023-11-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2023-12\2023-12-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-01\2024-01-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-02\2024-02-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-03\2024-03-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-04\2024-04-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-05\2024-05-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-06\2024-06-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-07\2024-07-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-08\2024-08-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-09\2024-09-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-10\2024-10-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-11\2024-11-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2024-12\2024-12-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-01\2025-01-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-02\2025-02-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-03\2025-03-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-04\2025-04-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-05\2025-05-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-06\2025-06-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-07\2025-07-south-wales-street.csv
# Loading: C:/Police forces\South Wales Police\2025-08\2025-08-south-wales-street.csv
# ✅ Data loaded successfully!
# Rows: 646436
# Columns: 13

# %% [markdown]
# Initial Exploration

# %%
df = pd.concat(all_data, ignore_index=True)

# %%
#  shape
df.shape
# Out:
# (646436, 13)

# %%
# Columns in the dataset
df.columns.tolist()
# Out:
# ['Crime ID',
#  'Month',
#  'Reported by',
#  'Falls within',
#  'Longitude',
#  'Latitude',
#  'Location',
#  'LSOA code',
#  'LSOA name',
#  'Crime type',
#  'Last outcome category',
#  'Context',
#  'PoliceForce']

# %%
# Data types
df.dtypes
# Out:
# Crime ID                  object
# Month                     object
# Reported by               object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# Location                  object
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# Context                  float64
# PoliceForce               object
# dtype: object

# %%
# Missing values
df.isnull().sum()
# Out:
# Crime ID                 102635
# Month                         0
# Reported by                   0
# Falls within                  0
# Longitude                 14653
# Latitude                  14653
# Location                      0
# LSOA code                 14653
# LSOA name                 14653
# Crime type                    0
# Last outcome category    102635
# Context                  646436
# PoliceForce                   0
# dtype: int64

# %%
# Rows per police force
df['PoliceForce'].value_counts()
# Out:
# PoliceForce
# South Wales Police    280967
# Gwent Police          147682
# North Wales Police    137459
# Dyfed-Powys Police     80328
# Name: count, dtype: int64

# %%
df.drop(columns=['Context'], inplace=True)

# %%
df = df.dropna(subset=['Latitude', 'Longitude'])

# %%
# Fill missing Crime IDs with placeholder if needed
df['Crime ID'] = df['Crime ID'].fillna('Unknown')

# Fill missing last outcome category
df['Last outcome category'] = df['Last outcome category'].fillna('Unknown')

# %%
df.isnull().sum()
df.shape
# Out:
# (631783, 12)

# %%
df.isnull().sum()
# Out:
# Crime ID                 0
# Month                    0
# Reported by              0
# Falls within             0
# Longitude                0
# Latitude                 0
# Location                 0
# LSOA code                0
# LSOA name                0
# Crime type               0
# Last outcome category    0
# PoliceForce              0
# dtype: int64

# %%
df.dtypes
# Out:
# Crime ID                  object
# Month                     object
# Reported by               object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# Location                  object
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# PoliceForce               object
# dtype: object

# %%
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# %%
df.dtypes
# Out:
# Crime ID                         object
# Month                    datetime64[ns]
# Reported by                      object
# Falls within                     object
# Longitude                       float64
# Latitude                        float64
# Location                         object
# LSOA code                        object
# LSOA name                        object
# Crime type                       object
# Last outcome category            object
# PoliceForce                      object
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['Month',
#  'Reported by',
#  'Falls within',
#  'Longitude',
#  'Latitude',
#  'Location',
#  'LSOA code',
#  'LSOA name',
#  'Crime type',
#  'Last outcome category',
#  'PoliceForce']

# %% [markdown]
# Checking for Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(26638)

# %% [markdown]
# Check for outliers

# %%
print(df['Latitude'].min(), df['Latitude'].max())
print(df['Longitude'].min(), df['Longitude'].max())
# Out:
# 50.230495 55.234185
# -5.306914 1.710476

# %%
df = df[(df['Latitude'] >= 49) & (df['Latitude'] <= 60)]
df = df[(df['Longitude'] >= -8) & (df['Longitude'] <= 2)]

# %%
df.head()
# Out:
#        Month         Reported by        Falls within  Longitude   Latitude  \
# 0 2023-08-01  Dyfed-Powys Police  Dyfed-Powys Police  -2.273464  53.599647
# 1 2023-08-01  Dyfed-Powys Police  Dyfed-Powys Police  -3.276655  51.754946
# 2 2023-08-01  Dyfed-Powys Police  Dyfed-Powys Police  -3.147151  51.480731
# 3 2023-08-01  Dyfed-Powys Police  Dyfed-Powys Police  -3.169263  51.464111
# 4 2023-08-01  Dyfed-Powys Police  Dyfed-Powys Police  -4.263992  51.997480
#
#                      Location  LSOA code             LSOA name  \
# 0  On or near Mossfield Close  E01004960             Bury 007E
# 1   On or near Hafod-Y-Mynydd  W01001376       Caerphilly 001C
# 2    On or near Hinton Street  W01001873          Cardiff 038C
# 3   On or near Adelaide Place  W01001942          Cardiff 049B
# 4       On or near Maes Cader  W01000685  Carmarthenshire 001A
#
#                      Crime type  \
# 0  Violence and sexual offences
# 1  Violence and sexual offences
# 2                   Other theft
# 3         Theft from the person
# 4                  Public order
#
#                            Last outcome category         PoliceForce
# 0                    Unable to prosecute suspect  Dyfed-Powys Police
# 1                    Unable to prosecute suspect  Dyfed-Powys Police
# 2                    Unable to prosecute suspect  Dyfed-Powys Police
# 3  Investigation complete; no suspect identified  Dyfed-Powys Police
# 4                    Unable to prosecute suspect  Dyfed-Powys Police

# %%
df.drop(columns=['Falls within', 'LSOA code'], inplace=True)

# %%
df.columns
# Out:
# Index(['Month', 'Reported by', 'Longitude', 'Latitude', 'Location',
#        'LSOA name', 'Crime type', 'Last outcome category', 'PoliceForce'],
#       dtype='object')

# %%
df.head()
# Out:
#        Month         Reported by  Longitude   Latitude  \
# 0 2023-08-01  Dyfed-Powys Police  -2.273464  53.599647
# 1 2023-08-01  Dyfed-Powys Police  -3.276655  51.754946
# 2 2023-08-01  Dyfed-Powys Police  -3.147151  51.480731
# 3 2023-08-01  Dyfed-Powys Police  -3.169263  51.464111
# 4 2023-08-01  Dyfed-Powys Police  -4.263992  51.997480
#
#                      Location             LSOA name  \
# 0  On or near Mossfield Close             Bury 007E
# 1   On or near Hafod-Y-Mynydd       Caerphilly 001C
# 2    On or near Hinton Street          Cardiff 038C
# 3   On or near Adelaide Place          Cardiff 049B
# 4       On or near Maes Cader  Carmarthenshire 001A
#
#                      Crime type  \
# 0  Violence and sexual offences
# 1  Violence and sexual offences
# 2                   Other theft
# 3         Theft from the person
# 4                  Public order
#
#                            Last outcome category         PoliceForce
# 0                    Unable to prosecute suspect  Dyfed-Powys Police
# 1                    Unable to prosecute suspect  Dyfed-Powys Police
# 2                    Unable to prosecute suspect  Dyfed-Powys Police
# 3  Investigation complete; no suspect identified  Dyfed-Powys Police
# 4                    Unable to prosecute suspect  Dyfed-Powys Police

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 631783 entries, 0 to 646157
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Month                  631783 non-null  datetime64[ns]
#  1   Reported by            631783 non-null  object
#  2   Longitude              631783 non-null  float64
#  3   Latitude               631783 non-null  float64
#  4   Location               631783 non-null  object
#  5   LSOA name              631783 non-null  object
#  6   Crime type             631783 non-null  object
#  7   Last outcome category  631783 non-null  object
#  8   PoliceForce            631783 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 48.2+ MB

# %%
df.describe()
# Out:
#                                Month      Longitude       Latitude
# count                         631783  631783.000000  631783.000000
# mean   2024-08-04 04:35:38.017641984      -3.474004      51.984864
# min              2023-08-01 00:00:00      -5.306914      50.230495
# 25%              2024-02-01 00:00:00      -3.806786      51.577644
# 50%              2024-08-01 00:00:00      -3.283419      51.662443
# 75%              2025-03-01 00:00:00      -3.139517      52.092867
# max              2025-08-01 00:00:00       1.710476      55.234185
# std                              NaN       0.487121       0.656775

# %%
df[df['Month'] > '2024-12-31'].shape
# Out:
# (205693, 9)

# %%
df = df[(df['Month'] >= '2023-08-01') & (df['Month'] <= '2025-08-31')]

# %%
df.shape
# Out:
# (631783, 9)

# %%
print(df.shape)
print(df.isnull().sum())
print(df.dtypes)
df.head()
# Out:
# (631783, 9)
# Month                    0
# Reported by              0
# Longitude                0
# Latitude                 0
# Location                 0
# LSOA name                0
# Crime type               0
# Last outcome category    0
# PoliceForce              0
# dtype: int64
# Month                    datetime64[ns]
# Reported by                      object
# Longitude                       float64
# Latitude                        float64
# Location                         object
# LSOA name                        object
# Crime type                       object
# Last outcome category            object
# PoliceForce                      object
# dtype: object
#        Month         Reported by  Longitude   Latitude  \
# 0 2023-08-01  Dyfed-Powys Police  -2.273464  53.599647
# 1 2023-08-01  Dyfed-Powys Police  -3.276655  51.754946
# 2 2023-08-01  Dyfed-Powys Police  -3.147151  51.480731
# 3 2023-08-01  Dyfed-Powys Police  -3.169263  51.464111
# 4 2023-08-01  Dyfed-Powys Police  -4.263992  51.997480
#
#                      Location             LSOA name  \
# 0  On or near Mossfield Close             Bury 007E
# 1   On or near Hafod-Y-Mynydd       Caerphilly 001C
# 2    On or near Hinton Street          Cardiff 038C
# 3   On or near Adelaide Place          Cardiff 049B
# 4       On or near Maes Cader  Carmarthenshire 001A
#
#                      Crime type  \
# 0  Violence and sexual offences
# 1  Violence and sexual offences
# 2                   Other theft
# 3         Theft from the person
# 4                  Public order
#
#                            Last outcome category         PoliceForce
# 0                    Unable to prosecute suspect  Dyfed-Powys Police
# 1                    Unable to prosecute suspect  Dyfed-Powys Police
# 2                    Unable to prosecute suspect  Dyfed-Powys Police
# 3  Investigation complete; no suspect identified  Dyfed-Powys Police
# 4                    Unable to prosecute suspect  Dyfed-Powys Police
